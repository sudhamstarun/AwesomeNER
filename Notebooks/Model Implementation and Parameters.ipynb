# %%
import json

from keras.models import Model, model_from_json
from keras.layers.merge import Concatenate
from keras.layers import Dense, LSTM, Bidirectional, Embedding, Input, Dropout, TimeDistributed
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-7d440abc58f8> in <module>
#       1 import json
#       2
# ----> 3 from keras.models import Model, model_from_json
#       4 from keras.layers.merge import Concatenate
#       5 from keras.layers import Dense, LSTM, Bidirectional, Embedding, Input, Dropout, TimeDistributed
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/keras/__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/keras/utils/__init__.py in <module>
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/keras/utils/conv_utils.py in <module>
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/keras/backend/__init__.py in <module>
#      85 elif _BACKEND == 'tensorflow':
#      86     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 87     from .tensorflow_backend import *
#      88 else:
#      89     # Try and load external backend.
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in <module>
#       3 from __future__ import print_function
#       4
# ----> 5 import tensorflow as tf
#       6 from tensorflow.python.framework import ops as tf_ops
#       7 from tensorflow.python.training import moving_averages
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/tensorflow/__init__.py in <module>
#      22
#      23 # pylint: disable=g-bad-import-order
# ---> 24 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      25
#      26 try:
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/tensorflow/python/__init__.py in <module>
#      68
#      69 # Framework
# ---> 70 from tensorflow.python.framework.framework_lib import *  # pylint: disable=redefined-builtin
#      71 from tensorflow.python.framework.versions import *
#      72 from tensorflow.python.framework import errors
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/tensorflow/python/framework/framework_lib.py in <module>
#      50 from tensorflow.python.framework.random_seed import set_random_seed
#      51 from tensorflow.python.framework.sparse_tensor import convert_to_tensor_or_sparse_tensor
# ---> 52 from tensorflow.python.framework.importer import import_graph_def
#      53
#      54 # Utilities for working with Tensors
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/tensorflow/python/framework/importer.py in <module>
#      25 from tensorflow.python.framework import device as pydev
#      26 from tensorflow.python.framework import errors
# ---> 27 from tensorflow.python.framework import function
#      28 from tensorflow.python.framework import op_def_registry
#      29 from tensorflow.python.framework import ops
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/tensorflow/python/framework/function.py in <module>
#      34 from tensorflow.python.framework import ops
#      35 from tensorflow.python.ops import array_ops
# ---> 36 from tensorflow.python.ops import resource_variable_ops
#      37 from tensorflow.python.ops import variable_scope as vs
#      38 from tensorflow.python.util import compat
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py in <module>
#      36 from tensorflow.python.ops import gen_state_ops
#      37 from tensorflow.python.ops import math_ops
# ---> 38 from tensorflow.python.ops import variables
#      39 # go/tf-wildcard-import
#      40 # pylint: disable=wildcard-import
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/tensorflow/python/ops/variables.py in <module>
#      35 from tensorflow.python.ops import state_ops
#      36 from tensorflow.python.platform import tf_logging as logging
# ---> 37 from tensorflow.python.training.checkpointable import base as checkpointable
#      38 from tensorflow.python.util import compat
#      39 from tensorflow.python.util import tf_should_use
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/tensorflow/python/training/checkpointable/base.py in <module>
#      33 from tensorflow.python.ops import array_ops
#      34 from tensorflow.python.ops import control_flow_ops
# ---> 35 from tensorflow.python.ops import gen_io_ops as io_ops
#      36 from tensorflow.python.platform import tf_logging as logging
#      37 from tensorflow.python.training import saveable_object
#
# ~/Code/AwesomeNER/bilstm-crf/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py in <module>
#      22 from tensorflow.python.framework import ops as _ops
#      23 from tensorflow.python.framework import op_def_library as _op_def_library
# ---> 24 from tensorflow.python.util.deprecation import deprecated_endpoints
#      25 from tensorflow.python.util.tf_export import tf_export
#      26
#
# ImportError: cannot import name 'deprecated_endpoints'

# %%
class BiLSTMCRF_Model(object):
